# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("integración.csv")
data
# Out:
#        #                                        Escuela       SEXO  \
# 0      1  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 1      2  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 2      3  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 3      4  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 4      5  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# ..   ...                                            ...        ...
# 768  769      Esc. Miguel Hidalgo, Atitalaquia, Hidalgo   Femenino
# 769  770      Esc. Miguel Hidalgo, Atitalaquia, Hidalgo   Femenino
# 770  771      Esc. Miguel Hidalgo, Atitalaquia, Hidalgo  Masculino
# 771  772      Esc. Miguel Hidalgo, Atitalaquia, Hidalgo  Masculino
# 772  773      Esc. Miguel Hidalgo, Atitalaquia, Hidalgo  Masculino
#
#      Edad en anos  Z Talla para la edad  percentil Talla para la edad  \
# 0               6              1.514941  93.510628             Normal
# 1               7              1.315150  90.577032             Normal
# 2               6              0.004362  50.174010             Normal
# 3               7              1.315150  90.577032             Normal
# 4               6             -0.171990  43.172288             Normal
# ..            ...                   ...        ...                ...
# 768            11             -0.619082  26.793123             Normal
# 769            11              0.496614  69.026947             Normal
# 770            11              0.288097  61.336361             Normal
# 771            11              3.186197  99.927922               Alto
# 772            11              2.063327  98.045922               Alto
#
#      Z Longitud relativa de pierna  percentil.1 Longitud relativa de pierna  \
# 0                        -0.584420    27.946904                      Normal
# 1                        -1.025081    15.266246                      Normal
# 2                        -1.353775     8.790415                      Normal
# 3                        -0.160604    43.620256                      Normal
# 4                         0.089080    53.549080                      Normal
# ..                             ...          ...                         ...
# 768                      -1.889259     2.942859              Piernas cortas
# 769                      -0.834238    20.207337                      Normal
# 770                      -1.680407     4.643906              Piernas cortas
# 771                      -0.272509    39.261546                      Normal
# 772                      -1.689944     4.551938              Piernas cortas
#
#         Z IMC  percentil.2 indice de Masa Corporal
# 0    1.993205    97.688050                Obesidad
# 1   -0.524365    30.001223                  Normal
# 2    1.801321    96.417381                Obesidad
# 3    1.266555    89.734282                Obesidad
# 4    0.514550    69.656631                  Normal
# ..        ...          ...                     ...
# 768  1.140078    87.287314                Obesidad
# 769  1.543358    93.862801                Obesidad
# 770  3.487683    99.975639                Obesidad
# 771  3.235996    99.939390                Obesidad
# 772  3.477788    99.974722                Obesidad
#
# [773 rows x 13 columns]

# %%
data["Escuela"]
# Out:
# 0      Esc. 17 de abril de 1869, Xochitepec, Morelos
# 1      Esc. 17 de abril de 1869, Xochitepec, Morelos
# 2      Esc. 17 de abril de 1869, Xochitepec, Morelos
# 3      Esc. 17 de abril de 1869, Xochitepec, Morelos
# 4      Esc. 17 de abril de 1869, Xochitepec, Morelos
#                            ...
# 768        Esc. Miguel Hidalgo, Atitalaquia, Hidalgo
# 769        Esc. Miguel Hidalgo, Atitalaquia, Hidalgo
# 770        Esc. Miguel Hidalgo, Atitalaquia, Hidalgo
# 771        Esc. Miguel Hidalgo, Atitalaquia, Hidalgo
# 772        Esc. Miguel Hidalgo, Atitalaquia, Hidalgo
# Name: Escuela, Length: 773, dtype: object

# %%
dups = data.pivot_table(index = ['Escuela'], aggfunc ='size')
dups
# Out:
# Escuela
# Esc. 17 de abril de 1869, Xochitepec, Morelos    140
# Esc. Emiliano Zapata, Naucalpan, Edo Mex         284
# Esc. Eufemio Zapata, Tlaquiltenango, Morelos      19
# Esc. Jose Tapia Bujalance, Iztapalapa, CdMx       66
# Esc. Miguel Hidalgo, Atitalaquia, Hidalgo        264
# dtype: int64

# %%
dups.index.values[0]
# Out:
# 'Esc. 17 de abril de 1869, Xochitepec, Morelos'

# %%
seleccion=dups.index.values[0]
seleccion
# Out:
# 'Esc. 17 de abril de 1869, Xochitepec, Morelos'

# %%
data[(data.Escuela==seleccion)]
# Out:
#        #                                        Escuela       SEXO  \
# 0      1  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 1      2  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 2      3  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 3      4  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 4      5  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# ..   ...                                            ...        ...
# 135  136  Esc. 17 de abril de 1869, Xochitepec, Morelos  Masculino
# 136  137  Esc. 17 de abril de 1869, Xochitepec, Morelos  Masculino
# 137  138  Esc. 17 de abril de 1869, Xochitepec, Morelos  Masculino
# 138  139  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
# 139  140  Esc. 17 de abril de 1869, Xochitepec, Morelos   Femenino
#
#      Edad en anos  Z Talla para la edad  percentil Talla para la edad  \
# 0               6              1.514941  93.510628             Normal
# 1               7              1.315150  90.577032             Normal
# 2               6              0.004362  50.174010             Normal
# 3               7              1.315150  90.577032             Normal
# 4               6             -0.171990  43.172288             Normal
# ..            ...                   ...        ...                ...
# 135             9             -1.668276   4.763048       Desnutricion
# 136            10             -0.566629  28.548325             Normal
# 137            10              0.870612  80.801694             Normal
# 138            11             -0.322899  37.338596             Normal
# 139            11              1.521319  93.591010             Normal
#
#      Z Longitud relativa de pierna  percentil.1 Longitud relativa de pierna  \
# 0                        -0.584420    27.946904                      Normal
# 1                        -1.025081    15.266246                      Normal
# 2                        -1.353775     8.790415                      Normal
# 3                        -0.160604    43.620256                      Normal
# 4                         0.089080    53.549080                      Normal
# ..                             ...          ...                         ...
# 135                      -0.944391    17.248506                      Normal
# 136                      -0.815717    20.733088                      Normal
# 137                       0.019001    50.758003                      Normal
# 138                      -1.368742     8.553990                      Normal
# 139                       0.308154    62.101729                      Normal
#
#         Z IMC  percentil.2 indice de Masa Corporal
# 0    1.993205    97.688050                Obesidad
# 1   -0.524365    30.001223                  Normal
# 2    1.801321    96.417381                Obesidad
# 3    1.266555    89.734282                Obesidad
# 4    0.514550    69.656631                  Normal
# ..        ...          ...                     ...
# 135 -0.704081    24.069105                  Normal
# 136  1.811415    96.496166                Obesidad
# 137 -0.205353    41.864804                  Normal
# 138  2.367158    99.103736                Obesidad
# 139  0.004080    50.162755                  Normal
#
# [140 rows x 13 columns]
